# %% [markdown]
# - This notebook is to refine latent space plot and plot model performance for NN

# %%
import sys
sys.path.append("../src/models")
sys.path.append("../src")
sys.path.append("../")

# %%
from model_comparison import *

# %%
import os
import joblib
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
# Baseline
df01 = pd.read_csv('df_total_surfactants_baseline_20250711.csv')
df02 = pd.read_csv('df_combined_bm_baseline_20250527.csv')
df03 = pd.read_csv('df_total_amphiphiles_baseline_20250710.csv')
# VICGAE
df11 = pd.read_csv('df_total_surfactants_VICGAE_20250707.csv')
df12 = pd.read_csv('df_total_binary_VICGAE_20250707.csv')
df13 = pd.read_csv('df_total_amphiphiles_VICGAE_20250707.csv')
# Chemprop
df21 = pd.read_csv('df_total_surfactants_chemprop_20250707.csv')
df22 = pd.read_csv('df_total_binary_chemprop_20250707.csv')
df23 = pd.read_csv('df_total_amphiphiles_chemprop_20250707.csv')
# Chemeleon
df31 = pd.read_csv('df_total_surfactants_chemeleon_20250707.csv')
df32 = pd.read_csv('df_total_binary_chemeleon_20250707.csv')
df33 = pd.read_csv('df_total_amphiphiles_chemleon_20250702.csv')
# SMI-TED
df41 = pd.read_csv('df_total_surfactants_smi-ted_20250709.csv')
df42 = pd.read_csv('df_total_20250501.csv')
df43 = pd.read_csv('df_total_amphiphiles_smi-ted_20250709.csv')

# %%
# For surfactants data
model_type = ['Fingerprint', 'VICGAE', 'Chemprop', 'Chemeleon', 'SMI-TED']
dfs = [df01, df11, df21, df31, df41]

results_dict1 = {}

for df, model in zip(dfs, model_type):
    print(model)
    # results_df = evaluate_model_performance_regression(df, data_type='surfactants', model_type=model)
    # results_dict1[model] = results_df
    visualize_latent_space(df, data_type='surfactants', model_type=model)
# Out:
# Fingerprint
# OMP: Info #276: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.
# VICGAE
# Chemprop
# Chemeleon
# SMI-TED

# %%
# For binary aqueous data
# label 1 is miscible, red
model_type = ['Fingerprint', 'VICGAE', 'Chemprop', 'Chemeleon', 'SMI-TED']
dfs = [df02, df12, df22, df32, df42]

results_dict1 = {}

for df, model in zip(dfs, model_type):
    print(model)
    # results_df = evaluate_model_performance(df, data_type='surfactants', model_type=model)
    # results_dict1[model] = results_df
    visualize_latent_space(df, data_type='binary_aqueous', model_type=model)
# Out:
# Fingerprint
# OMP: Info #276: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.
# VICGAE
# Chemprop
# Chemeleon
# SMI-TED

# %%
# Use log scale weighted concentration
# Baseline
df02 = pd.read_csv('df_total_binary_baseline_log_20250930.csv')
# VICGAE
df12 = pd.read_csv('df_total_binary_VICGAE_log_20250930.csv')
# Chemprop
df22 = pd.read_csv('df_total_binary_chemprop_log_20250930.csv')
# Chemeleon
df32 = pd.read_csv('df_total_binary_chemeleon_log_20250930.csv')
# SMI-TED
df42 = pd.read_csv('df_total_binary_SMI-TED_log_20250930.csv')

# %%
model_type = ['Fingerprint', 'VICGAE', 'Chemprop', 'Chemeleon', 'SMI-TED']
dfs = [df02, df12, df22, df32, df42]

results_dict1 = {}

for df, model in zip(dfs, model_type):
    print(model)
    visualize_latent_space(df, data_type='binary_aqueous', model_type=model)
# Out:
# Fingerprint
# OMP: Info #276: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.
# VICGAE
# Chemprop
# Chemeleon
# SMI-TED

# %%
# For amphiphiles data
# label 1 vesicles formation, red
model_type = ['Fingerprint', 'VICGAE', 'Chemprop', 'Chemeleon', 'SMI-TED']
dfs = [df03, df13, df23, df33, df43]

results_dict1 = {}

for df, model in zip(dfs, model_type):
    print(model)
    # results_df = evaluate_model_performance(df, data_type='surfactants', model_type=model)
    # results_dict1[model] = results_df
    visualize_latent_space(df, data_type='amphiphile', model_type=model)
# Out:
# Fingerprint
# OMP: Info #276: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.
# VICGAE
# Chemprop
# Chemeleon
# SMI-TED

# %% [markdown]
# ### Surfactants with NN model

# %%
import joblib

# %%
results_surf_NN = joblib.load("regression_results_surfactants.joblib")

# %%
plot_results_surf_NN(results_surf_NN)
# Out:
# Saved plots for Fingerprint:
#   Boxplot: ../../results/Fingerprint_regression_metrics.png
#   Scatter: ../../results/Fingerprint_scatter.png
# Saved plots for VICGAE:
#   Boxplot: ../../results/VICGAE_regression_metrics.png
#   Scatter: ../../results/VICGAE_scatter.png
# Saved plots for Chemprop:
#   Boxplot: ../../results/Chemprop_regression_metrics.png
#   Scatter: ../../results/Chemprop_scatter.png
# Saved plots for Chemeleon:
#   Boxplot: ../../results/Chemeleon_regression_metrics.png
#   Scatter: ../../results/Chemeleon_scatter.png
# Saved plots for SMI-TED:
#   Boxplot: ../../results/SMI-TED_regression_metrics.png
#   Scatter: ../../results/SMI-TED_scatter.png

# %%
# Binary

# %%
results_binary_NN = joblib.load("NN_classification_results_binary_update.joblib")

# %%
plot_roc_classification(results_binary_NN, save_dir="../../results/Binary_NN_model_performance", data_type="binary")

# %%
# Amphiphile

# %%
results_amphiphile_NN = joblib.load("NN_classification_results_amphiphile.joblib")

# %%
plot_roc_classification(results_amphiphile_NN, save_dir="../../results/Amphiphile_NN_model_performance", data_type="amphiphile")
