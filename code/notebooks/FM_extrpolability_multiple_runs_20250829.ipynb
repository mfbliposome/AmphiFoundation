# %% [markdown]
# - This notebook is to run multiple repeated runs in order to show the variance

# %%
import sys
sys.path.append("../src/models")
sys.path.append("../src")
sys.path.append("../")

# %%
from Extrapolability import get_sample_fromGP, get_sample_lack_feature, classifier_performance_update, get_sample_lack_features_mul, run_multiple, run_multiple_multi_feature
from utils import get_molecule_representation, get_latent_space, run_classifier_update

# %%
model_path = '/Users/haoliu/Documents/GitHub/MicroscopyAnalysis/GPC_model_20240713.pkl'
info_path = '/Users/haoliu/Documents/Hao/Fordham/Cheminformatics/MD/Amphiphiles/Info.csv'

# %%
run_multiple("conc7", model_path, info_path, n_runs=10)
# Out:
# /Users/haoliu/anaconda3/envs/ActiveLearning/lib/python3.11/site-packages/sklearn/base.py:432: UserWarning: X has feature names, but GaussianProcessClassifier was fitted without feature names
#   warnings.warn(
# Random Seed: 12345
# Using Rotation Embedding
# Using Rotation Embedding
# Using Rotation Embedding
# Using Rotation Embedding
# Using Rotation Embedding
# Using Rotation Embedding
# Using Rotation Embedding
# Using Rotation Embedding
# Using Rotation Embedding
# Using Rotation Embedding
# Using Rotation Embedding
# Using Rotation Embedding
# /Users/haoliu/anaconda3/envs/ActiveLearning/lib/python3.11/site-packages/numpy/core/fromnumeric.py:59: FutureWarning: 'Series.swapaxes' is deprecated and will be removed in a future version. Please use 'Series.transpose' instead.
#   return bound(*args, **kwds)
# Vocab size: 2393
# [INFERENCE MODE - smi-ted-Light]
# 100%|██████████| 7/7 [00:02<00:00,  3.00it/s]
# ...

# %%
# %%time
feature_list = ['conc1', 'conc2', 'conc3', 'conc4', 'conc5', 'conc6']
for Feature in feature_list:
    print(f"\n--- Processing Feature: {Feature} ---")
    run_multiple(Feature, model_path, info_path, n_runs=10)
# Out:
# --- Processing Feature: conc1 ---
# /Users/haoliu/anaconda3/envs/ActiveLearning/lib/python3.11/site-packages/sklearn/base.py:432: UserWarning: X has feature names, but GaussianProcessClassifier was fitted without feature names
#   warnings.warn(
# Random Seed: 12345
# Using Rotation Embedding
# Using Rotation Embedding
# Using Rotation Embedding
# Using Rotation Embedding
# Using Rotation Embedding
# Using Rotation Embedding
# Using Rotation Embedding
# Using Rotation Embedding
# Using Rotation Embedding
# Using Rotation Embedding
# Using Rotation Embedding
# Using Rotation Embedding
# /Users/haoliu/anaconda3/envs/ActiveLearning/lib/python3.11/site-packages/numpy/core/fromnumeric.py:59: FutureWarning: 'Series.swapaxes' is deprecated and will be removed in a future version. Please use 'Series.transpose' instead.
#   return bound(*args, **kwds)
# Vocab size: 2393
# [INFERENCE MODE - smi-ted-Light]
# 100%|██████████| 7/7 [00:01<00:00,  5.05it/s]
# ...

# %% [markdown]
# ### Multi features case

# %%
feature_list_combo =\
[['conc1', 'conc4'],
 ['conc1', 'conc2', 'conc7'],
 ['conc1', 'conc2', 'conc5', 'conc6'],
 ['conc1', 'conc2', 'conc3', 'conc5', 'conc6'],
 ['conc2', 'conc3', 'conc4', 'conc5', 'conc6', 'conc7'],
 ['conc1', 'conc2', 'conc3', 'conc4', 'conc5', 'conc6', 'conc7']]

# %%
for Feature in feature_list_combo:
    print(Feature)
    run_multiple_multi_feature(Feature, model_path, info_path, n_runs=10)
# Out:
# ['conc1', 'conc4']
# /Users/haoliu/anaconda3/envs/ActiveLearning/lib/python3.11/site-packages/sklearn/base.py:432: UserWarning: X has feature names, but GaussianProcessClassifier was fitted without feature names
#   warnings.warn(
# Random Seed: 12345
# Using Rotation Embedding
# Using Rotation Embedding
# Using Rotation Embedding
# Using Rotation Embedding
# Using Rotation Embedding
# Using Rotation Embedding
# Using Rotation Embedding
# Using Rotation Embedding
# Using Rotation Embedding
# Using Rotation Embedding
# Using Rotation Embedding
# Using Rotation Embedding
# /Users/haoliu/anaconda3/envs/ActiveLearning/lib/python3.11/site-packages/numpy/core/fromnumeric.py:59: FutureWarning: 'Series.swapaxes' is deprecated and will be removed in a future version. Please use 'Series.transpose' instead.
#   return bound(*args, **kwds)
# Vocab size: 2393
# [INFERENCE MODE - smi-ted-Light]
# 100%|██████████| 7/7 [00:01<00:00,  6.90it/s]
# ...

# %%
for Feature in feature_list_combo:
    print(Feature)
    run_multiple_multi_feature(Feature, model_path, info_path, n_runs=10)
# Out:
# ['conc1', 'conc4']
# /Users/haoliu/anaconda3/envs/ActiveLearning/lib/python3.11/site-packages/sklearn/base.py:432: UserWarning: X has feature names, but GaussianProcessClassifier was fitted without feature names
#   warnings.warn(
# Random Seed: 12345
# Using Rotation Embedding
# Using Rotation Embedding
# Using Rotation Embedding
# Using Rotation Embedding
# Using Rotation Embedding
# Using Rotation Embedding
# Using Rotation Embedding
# Using Rotation Embedding
# Using Rotation Embedding
# Using Rotation Embedding
# Using Rotation Embedding
# Using Rotation Embedding
# /Users/haoliu/anaconda3/envs/ActiveLearning/lib/python3.11/site-packages/numpy/core/fromnumeric.py:59: FutureWarning: 'Series.swapaxes' is deprecated and will be removed in a future version. Please use 'Series.transpose' instead.
#   return bound(*args, **kwds)
# Vocab size: 2393
# [INFERENCE MODE - smi-ted-Light]
# 100%|██████████| 7/7 [00:00<00:00,  7.51it/s]
# ...
