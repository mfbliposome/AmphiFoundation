# %% [markdown]
# - This notebook is fine tune model after doing the second experiments

# %%
import sys
sys.path.append("../src/models")
sys.path.append("../src")
sys.path.append("../")

# %%
import pandas as pd
import joblib

# %%
from utils import *

# %%
# Load previsous data and model

# %%
df_init = pd.read_csv('../../data/Intermediate/df_update_1st_exp.csv')

# %%
# Get new data and results

# %%
# Load the formulation for second experimental plan

# %%
data = joblib.load("experiment_plan_20250810.joblib")

# Extract objects
conc4 = data["conc4"]
dispense_df4 = data["dispense_df4"]
selected_df4 = data["selected_df4"]
probs4 = data["probs4"]

conc2 = data["conc2"]
dispense_df2 = data["dispense_df2"]
selected_df2 = data["selected_df2"]
probs2 = data["probs2"]

conc2_old = data["conc2_old"]
dispense_df2_old = data["dispense_df2_old"]
selected_df2_old = data["selected_df2_old"]
probs2_old = data["probs2_old"]

# %%
top10 = pd.read_csv('top10_highprob_replace_smi5.csv')

# %%
df_new_exp = pd.concat([selected_df4, selected_df2, selected_df2_old, top10],)
df_new_exp.shape
# Out:
# (40, 15)

# %%
# Load an old dataset
import pickle

info_path = '../../data/Info_new_molecules.csv'
df_info = pd.read_csv(info_path)

output_file = "../../data/Intermediate/selected_samples_20250603.pkl"

with open(output_file, 'rb') as f:
    loaded_list = pickle.load(f)
    
high_samples4 = loaded_list[8]# high_dissimilar3 before fine-tune

# %%
df_hierarchical = pd.concat([selected_df4, high_samples4, selected_df2, selected_df2_old, top10],)

# %%
df_hierarchical.reset_index(drop=True, inplace=True)
df_hierarchical
# Out:
# /Users/haoliu/anaconda3/envs/ActiveLearning/lib/python3.11/site-packages/rdkit/Chem/PandasPatcher.py:132: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   for col in df_subset.columns[df_subset.applymap(MolFormatter.is_mol).any()]
#                                                  smi1     conc1  \
# 0   C(C(C(C(C(F)(F)S(=O)(=O)[O-])(F)F)(F)F)(F)F)(C...  0.660667
# 1   C(C(C(C(C(F)(F)S(=O)(=O)[O-])(F)F)(F)F)(F)F)(C...  1.551979
# 2   C(C(C(C(C(F)(F)S(=O)(=O)[O-])(F)F)(F)F)(F)F)(C...  1.115216
# 3   C(C(C(C(C(F)(F)S(=O)(=O)[O-])(F)F)(F)F)(F)F)(C...  0.730293
# 4   C(C(C(C(C(F)(F)S(=O)(=O)[O-])(F)F)(F)F)(F)F)(C...  0.332417
# 5   C(C(C(C(C(F)(F)S(=O)(=O)[O-])(F)F)(F)F)(F)F)(C...  0.691710
# 6   C(C(C(C(C(F)(F)S(=O)(=O)[O-])(F)F)(F)F)(F)F)(C...  0.962129
# 7   C(C(C(C(C(F)(F)S(=O)(=O)[O-])(F)F)(F)F)(F)F)(C...  0.909160
# 8   C(C(C(C(C(F)(F)S(=O)(=O)[O-])(F)F)(F)F)(F)F)(C...  0.139282
# 9   C(C(C(C(C(F)(F)S(=O)(=O)[O-])(F)F)(F)F)(F)F)(C...  1.723777
# 10  C(C(C(C(C(F)(F)S(=O)(=O)[O-])(F)F)(F)F)(F)F)(C...  0.331215
# 11  C(C(C(C(C(F)(F)S(=O)(=O)[O-])(F)F)(F)F)(F)F)(C...  0.043011
# 12  C(C(C(C(C(F)(F)S(=O)(=O)[O-])(F)F)(F)F)(F)F)(C...  0.001171
# 13  C(C(C(C(C(F)(F)S(=O)(=O)[O-])(F)F)(F)F)(F)F)(C...  0.027584
# 14  C(C(C(C(C(F)(F)S(=O)(=O)[O-])(F)F)(F)F)(F)F)(C...  1.332899
# 15  C(C(C(C(C(F)(F)S(=O)(=O)[O-])(F)F)(F)F)(F)F)(C...  1.656296
# 16  C(C(C(C(C(F)(F)S(=O)(=O)[O-])(F)F)(F)F)(F)F)(C...  1.158299
# 17  C(C(C(C(C(F)(F)S(=O)(=O)[O-])(F)F)(F)F)(F)F)(C...  0.846215
# 18  C(C(C(C(C(F)(F)S(=O)(=O)[O-])(F)F)(F)F)(F)F)(C...  0.622356
# 19  C(C(C(C(C(F)(F)S(=O)(=O)[O-])(F)F)(F)F)(F)F)(C...  1.113275
# 20                               CC(=CCC/C(=C/CO)/C)C  1.339536
# 21                               CC(=CCC/C(=C/CO)/C)C  0.485739
# 22                               CC(=CCC/C(=C/CO)/C)C  1.639621
# 23                               CC(=CCC/C(=C/CO)/C)C  0.922637
# 24                               CC(=CCC/C(=C/CO)/C)C  0.959214
# 25                               CC(=CCC/C(=C/CO)/C)C  1.040923
# 26                               CC(=CCC/C(=C/CO)/C)C  1.684118
# 27                               CC(=CCC/C(=C/CO)/C)C  0.514303
# 28                               CC(=CCC/C(=C/CO)/C)C  0.986656
# 29                               CC(=CCC/C(=C/CO)/C)C  0.917848
# 30                               CC(=CCC/C(=C/CO)/C)C  0.058131
# 31                               CC(=CCC/C(=C/CO)/C)C  0.229427
# 32                               CC(=CCC/C(=C/CO)/C)C  0.833772
# 33                               CC(=CCC/C(=C/CO)/C)C  0.491230
# 34                               CC(=CCC/C(=C/CO)/C)C  0.089993
# 35                               CC(=CCC/C(=C/CO)/C)C  0.277339
# 36                               CC(=CCC/C(=C/CO)/C)C  0.595629
# 37                               CC(=CCC/C(=C/CO)/C)C  0.635940
# 38                               CC(=CCC/C(=C/CO)/C)C  0.276864
# 39                               CC(=CCC/C(=C/CO)/C)C  0.488477
# 40                                       CCCCCCCCCC=O  0.867593
# 41                                       CCCCCCCCCC=O  0.355003
# 42                                       CCCCCCCCCC=O  1.115505
# 43                                       CCCCCCCCCC=O  0.492547
# 44                                       CCCCCCCCCC=O  0.908843
# 45                                       CCCCCCCCCC=O  0.705383
# 46                                       CCCCCCCCCC=O  0.874117
# 47                                       CCCCCCCCCC=O  1.383261
# 48                                       CCCCCCCCCC=O  0.731110
# 49                                       CCCCCCCCCC=O  0.353304
#
#                     smi2     conc2                   smi3     conc3  \
# 0     CCCCCCCCCC(=O)[O-]  1.379174            CCCCCCCCCCN  1.453001
# 1     CCCCCCCCCC(=O)[O-]  1.077054            CCCCCCCCCCN  1.268696
# 2     CCCCCCCCCC(=O)[O-]  1.399941            CCCCCCCCCCN  1.036172
# 3     CCCCCCCCCC(=O)[O-]  1.482715            CCCCCCCCCCN  1.369850
# 4     CCCCCCCCCC(=O)[O-]  1.556364            CCCCCCCCCCN  1.391475
# 5     CCCCCCCCCC(=O)[O-]  1.732105            CCCCCCCCCCN  1.249154
# 6     CCCCCCCCCC(=O)[O-]  1.062406            CCCCCCCCCCN  1.039375
# 7     CCCCCCCCCC(=O)[O-]  1.566397            CCCCCCCCCCN  0.884317
# 8     CCCCCCCCCC(=O)[O-]  1.745881            CCCCCCCCCCN  1.767052
# 9     CCCCCCCCCC(=O)[O-]  0.911932            CCCCCCCCCCN  0.811353
# 10    CCCCCCCCCC(=O)[O-]  1.737262            CCCCCCCCCCN  1.388852
# 11    CCCCCCCCCC(=O)[O-]  0.600905            CCCCCCCCCCN  0.317289
# 12    CCCCCCCCCC(=O)[O-]  1.560030            CCCCCCCCCCN  1.420139
# 13    CCCCCCCCCC(=O)[O-]  1.044463            CCCCCCCCCCN  0.453497
# 14    CCCCCCCCCC(=O)[O-]  1.647000            CCCCCCCCCCN  0.759294
# 15    CCCCCCCCCC(=O)[O-]  1.739903            CCCCCCCCCCN  1.691898
# 16    CCCCCCCCCC(=O)[O-]  1.745522            CCCCCCCCCCN  1.517729
# 17    CCCCCCCCCC(=O)[O-]  1.577029            CCCCCCCCCCN  0.386555
# 18    CCCCCCCCCC(=O)[O-]  1.612285            CCCCCCCCCCN  0.039102
# 19    CCCCCCCCCC(=O)[O-]  1.287770            CCCCCCCCCCN  0.198175
# 20    CCCCCCCCCC(=O)[O-]  0.900754    CCCCCCCCOC(=O)CN.Cl  0.416069
# 21    CCCCCCCCCC(=O)[O-]  1.070878    CCCCCCCCOC(=O)CN.Cl  1.551835
# 22    CCCCCCCCCC(=O)[O-]  0.955060    CCCCCCCCOC(=O)CN.Cl  0.283017
# 23    CCCCCCCCCC(=O)[O-]  0.289123    CCCCCCCCOC(=O)CN.Cl  0.149709
# 24    CCCCCCCCCC(=O)[O-]  1.138347    CCCCCCCCOC(=O)CN.Cl  0.352057
# 25    CCCCCCCCCC(=O)[O-]  1.775059    CCCCCCCCOC(=O)CN.Cl  1.355878
# 26    CCCCCCCCCC(=O)[O-]  0.614621    CCCCCCCCOC(=O)CN.Cl  1.770481
# 27    CCCCCCCCCC(=O)[O-]  1.105385    CCCCCCCCOC(=O)CN.Cl  1.758050
# 28    CCCCCCCCCC(=O)[O-]  0.722451    CCCCCCCCOC(=O)CN.Cl  1.493690
# 29    CCCCCCCCCC(=O)[O-]  0.873258    CCCCCCCCOC(=O)CN.Cl  1.120014
# 30    CCCCCCCCCC(=O)[O-]  1.180264    CCCCCCCCOC(=O)CN.Cl  0.953739
# 31    CCCCCCCCCC(=O)[O-]  0.272173    CCCCCCCCOC(=O)CN.Cl  0.248745
# 32    CCCCCCCCCC(=O)[O-]  0.024516    CCCCCCCCOC(=O)CN.Cl  0.146205
# 33    CCCCCCCCCC(=O)[O-]  0.142300    CCCCCCCCOC(=O)CN.Cl  0.153479
# 34    CCCCCCCCCC(=O)[O-]  0.130623    CCCCCCCCOC(=O)CN.Cl  0.721852
# 35    CCCCCCCCCC(=O)[O-]  0.539634    CCCCCCCCOC(=O)CN.Cl  0.446107
# 36    CCCCCCCCCC(=O)[O-]  0.565360    CCCCCCCCOC(=O)CN.Cl  0.191044
# 37    CCCCCCCCCC(=O)[O-]  0.093152    CCCCCCCCOC(=O)CN.Cl  0.056877
# 38    CCCCCCCCCC(=O)[O-]  0.787591    CCCCCCCCOC(=O)CN.Cl  0.914622
# 39    CCCCCCCCCC(=O)[O-]  0.740981    CCCCCCCCOC(=O)CN.Cl  0.218391
# 40  CC(=CCC/C(=C/CO)/C)C  0.113958  CCCCCCCCCCCCCCCC(=O)O  0.988492
# 41  CC(=CCC/C(=C/CO)/C)C  0.016486  CCCCCCCCCCCCCCCC(=O)O  1.123896
# 42  CC(=CCC/C(=C/CO)/C)C  0.018002  CCCCCCCCCCCCCCCC(=O)O  0.349107
# 43  CC(=CCC/C(=C/CO)/C)C  0.058769  CCCCCCCCCCCCCCCC(=O)O  0.753140
# 44  CC(=CCC/C(=C/CO)/C)C  0.074489  CCCCCCCCCCCCCCCC(=O)O  0.265795
# 45  CC(=CCC/C(=C/CO)/C)C  0.343791  CCCCCCCCCCCCCCCC(=O)O  0.109686
# 46  CC(=CCC/C(=C/CO)/C)C  0.196621  CCCCCCCCCCCCCCCC(=O)O  0.981812
# 47  CC(=CCC/C(=C/CO)/C)C  0.048677  CCCCCCCCCCCCCCCC(=O)O  0.116831
# 48  CC(=CCC/C(=C/CO)/C)C  0.342723  CCCCCCCCCCCCCCCC(=O)O  0.926551
# 49  CC(=CCC/C(=C/CO)/C)C  0.174894  CCCCCCCCCCCCCCCC(=O)O  0.298953
#
#                                                  smi4     conc4  \
# 0   C(=O)(C(C(C(C(C(C(C(F)(F)F)(F)F)(F)F)(F)F)(F)F...  0.717343
# 1   C(=O)(C(C(C(C(C(C(C(F)(F)F)(F)F)(F)F)(F)F)(F)F...  0.036882
# 2   C(=O)(C(C(C(C(C(C(C(F)(F)F)(F)F)(F)F)(F)F)(F)F...  0.263322
# 3   C(=O)(C(C(C(C(C(C(C(F)(F)F)(F)F)(F)F)(F)F)(F)F...  1.027626
# 4   C(=O)(C(C(C(C(C(C(C(F)(F)F)(F)F)(F)F)(F)F)(F)F...  1.381307
# 5   C(=O)(C(C(C(C(C(C(C(F)(F)F)(F)F)(F)F)(F)F)(F)F...  0.149116
# 6   C(=O)(C(C(C(C(C(C(C(F)(F)F)(F)F)(F)F)(F)F)(F)F...  0.163922
# 7   C(=O)(C(C(C(C(C(C(C(F)(F)F)(F)F)(F)F)(F)F)(F)F...  1.258279
# 8   C(=O)(C(C(C(C(C(C(C(F)(F)F)(F)F)(F)F)(F)F)(F)F...  1.250938
# 9   C(=O)(C(C(C(C(C(C(C(F)(F)F)(F)F)(F)F)(F)F)(F)F...  0.499353
# 10  C(=O)(C(C(C(C(C(C(C(F)(F)F)(F)F)(F)F)(F)F)(F)F...  1.683356
# 11  C(=O)(C(C(C(C(C(C(C(F)(F)F)(F)F)(F)F)(F)F)(F)F...  0.176352
# 12  C(=O)(C(C(C(C(C(C(C(F)(F)F)(F)F)(F)F)(F)F)(F)F...  1.124023
# 13  C(=O)(C(C(C(C(C(C(C(F)(F)F)(F)F)(F)F)(F)F)(F)F...  0.806747
# 14  C(=O)(C(C(C(C(C(C(C(F)(F)F)(F)F)(F)F)(F)F)(F)F...  0.613019
# 15  C(=O)(C(C(C(C(C(C(C(F)(F)F)(F)F)(F)F)(F)F)(F)F...  0.849678
# 16  C(=O)(C(C(C(C(C(C(C(F)(F)F)(F)F)(F)F)(F)F)(F)F...  0.042277
# 17  C(=O)(C(C(C(C(C(C(C(F)(F)F)(F)F)(F)F)(F)F)(F)F...  1.214478
# 18  C(=O)(C(C(C(C(C(C(C(F)(F)F)(F)F)(F)F)(F)F)(F)F...  1.189351
# 19  C(=O)(C(C(C(C(C(C(C(F)(F)F)(F)F)(F)F)(F)F)(F)F...  0.063769
# 20                             CCCC/C=C\CCCCCCCC(=O)O  1.611821
# 21                             CCCC/C=C\CCCCCCCC(=O)O  1.696319
# 22                             CCCC/C=C\CCCCCCCC(=O)O  1.246884
# 23                             CCCC/C=C\CCCCCCCC(=O)O  0.034275
# 24                             CCCC/C=C\CCCCCCCC(=O)O  0.379398
# 25                             CCCC/C=C\CCCCCCCC(=O)O  0.792484
# 26                             CCCC/C=C\CCCCCCCC(=O)O  0.869416
# 27                             CCCC/C=C\CCCCCCCC(=O)O  1.132058
# 28                             CCCC/C=C\CCCCCCCC(=O)O  1.459695
# 29                             CCCC/C=C\CCCCCCCC(=O)O  1.695339
# 30                             CCCC/C=C\CCCCCCCC(=O)O  0.185026
# 31                             CCCC/C=C\CCCCCCCC(=O)O  1.148293
# 32                             CCCC/C=C\CCCCCCCC(=O)O  0.463334
# 33                             CCCC/C=C\CCCCCCCC(=O)O  1.602175
# 34                             CCCC/C=C\CCCCCCCC(=O)O  0.529090
# 35                             CCCC/C=C\CCCCCCCC(=O)O  0.667085
# 36                             CCCC/C=C\CCCCCCCC(=O)O  0.657214
# 37                             CCCC/C=C\CCCCCCCC(=O)O  0.758515
# 38                             CCCC/C=C\CCCCCCCC(=O)O  0.463694
# 39                             CCCC/C=C\CCCCCCCC(=O)O  0.324576
# 40                        CCCCCCCCCC[N+](C)(C)C.[Br-]  1.507042
# 41                        CCCCCCCCCC[N+](C)(C)C.[Br-]  0.566869
# 42                        CCCCCCCCCC[N+](C)(C)C.[Br-]  0.880346
# 43                        CCCCCCCCCC[N+](C)(C)C.[Br-]  1.603804
# 44                        CCCCCCCCCC[N+](C)(C)C.[Br-]  1.767804
# 45                        CCCCCCCCCC[N+](C)(C)C.[Br-]  1.058780
# 46                        CCCCCCCCCC[N+](C)(C)C.[Br-]  0.814135
# 47                        CCCCCCCCCC[N+](C)(C)C.[Br-]  0.831253
# 48                        CCCCCCCCCC[N+](C)(C)C.[Br-]  1.627068
# 49                        CCCCCCCCCC[N+](C)(C)C.[Br-]  1.655104
#
#                               smi5     conc5  \
# 0   CCCCCCCCCCOS(=O)(=O)[O-].[Na+]  1.697070
# 1   CCCCCCCCCCOS(=O)(=O)[O-].[Na+]  1.737845
# 2   CCCCCCCCCCOS(=O)(=O)[O-].[Na+]  1.453339
# 3   CCCCCCCCCCOS(=O)(=O)[O-].[Na+]  1.713007
# 4   CCCCCCCCCCOS(=O)(=O)[O-].[Na+]  1.513648
# 5   CCCCCCCCCCOS(=O)(=O)[O-].[Na+]  1.546216
# 6   CCCCCCCCCCOS(=O)(=O)[O-].[Na+]  1.572199
# 7   CCCCCCCCCCOS(=O)(=O)[O-].[Na+]  1.778889
# 8   CCCCCCCCCCOS(=O)(=O)[O-].[Na+]  0.960556
# 9   CCCCCCCCCCOS(=O)(=O)[O-].[Na+]  1.718068
# 10  CCCCCCCCCCOS(=O)(=O)[O-].[Na+]  1.603315
# 11  CCCCCCCCCCOS(=O)(=O)[O-].[Na+]  1.714213
# 12  CCCCCCCCCCOS(=O)(=O)[O-].[Na+]  1.344296
# 13  CCCCCCCCCCOS(=O)(=O)[O-].[Na+]  1.715755
# 14  CCCCCCCCCCOS(=O)(=O)[O-].[Na+]  1.722868
# 15  CCCCCCCCCCOS(=O)(=O)[O-].[Na+]  1.544573
# 16  CCCCCCCCCCOS(=O)(=O)[O-].[Na+]  1.610004
# 17  CCCCCCCCCCOS(=O)(=O)[O-].[Na+]  1.088946
# 18  CCCCCCCCCCOS(=O)(=O)[O-].[Na+]  1.726171
# 19  CCCCCCCCCCOS(=O)(=O)[O-].[Na+]  1.781601
# 20           CCCCCCCCCCCCCCCC(=O)O  0.687841
# 21           CCCCCCCCCCCCCCCC(=O)O  0.189758
# 22           CCCCCCCCCCCCCCCC(=O)O  1.421334
# 23           CCCCCCCCCCCCCCCC(=O)O  0.296981
# 24           CCCCCCCCCCCCCCCC(=O)O  0.074353
# 25           CCCCCCCCCCCCCCCC(=O)O  1.267485
# 26           CCCCCCCCCCCCCCCC(=O)O  0.321019
# 27           CCCCCCCCCCCCCCCC(=O)O  0.465506
# 28           CCCCCCCCCCCCCCCC(=O)O  1.096254
# 29           CCCCCCCCCCCCCCCC(=O)O  1.038811
# 30           CCCCCCCCCCCCCCCC(=O)O  0.309121
# 31           CCCCCCCCCCCCCCCC(=O)O  0.325885
# 32           CCCCCCCCCCCCCCCC(=O)O  0.049905
# 33           CCCCCCCCCCCCCCCC(=O)O  0.343780
# 34           CCCCCCCCCCCCCCCC(=O)O  0.416377
# 35           CCCCCCCCCCCCCCCC(=O)O  0.456296
# 36           CCCCCCCCCCCCCCCC(=O)O  0.178271
# 37           CCCCCCCCCCCCCCCC(=O)O  0.151521
# 38           CCCCCCCCCCCCCCCC(=O)O  0.567015
# 39           CCCCCCCCCCCCCCCC(=O)O  1.220399
# 40  CCCCCCCCCCOS(=O)(=O)[O-].[Na+]  1.786114
# 41  CCCCCCCCCCOS(=O)(=O)[O-].[Na+]  1.743641
# 42  CCCCCCCCCCOS(=O)(=O)[O-].[Na+]  1.703074
# 43  CCCCCCCCCCOS(=O)(=O)[O-].[Na+]  1.760677
# 44  CCCCCCCCCCOS(=O)(=O)[O-].[Na+]  1.729261
# 45  CCCCCCCCCCOS(=O)(=O)[O-].[Na+]  1.772438
# 46  CCCCCCCCCCOS(=O)(=O)[O-].[Na+]  1.512885
# 47  CCCCCCCCCCOS(=O)(=O)[O-].[Na+]  1.629104
# 48  CCCCCCCCCCOS(=O)(=O)[O-].[Na+]  1.441245
# 49  CCCCCCCCCCOS(=O)(=O)[O-].[Na+]  1.471879
#
#                                                  smi6     conc6  \
# 0   C(CS(=O)(=O)O)C(C(C(C(C(C(F)(F)F)(F)F)(F)F)(F)...  0.372438
# 1   C(CS(=O)(=O)O)C(C(C(C(C(C(F)(F)F)(F)F)(F)F)(F)...  0.762760
# 2   C(CS(=O)(=O)O)C(C(C(C(C(C(F)(F)F)(F)F)(F)F)(F)...  0.582719
# 3   C(CS(=O)(=O)O)C(C(C(C(C(C(F)(F)F)(F)F)(F)F)(F)...  0.183693
# 4   C(CS(=O)(=O)O)C(C(C(C(C(C(F)(F)F)(F)F)(F)F)(F)...  0.697319
# 5   C(CS(=O)(=O)O)C(C(C(C(C(C(F)(F)F)(F)F)(F)F)(F)...  0.440333
# 6   C(CS(=O)(=O)O)C(C(C(C(C(C(F)(F)F)(F)F)(F)F)(F)...  0.243367
# 7   C(CS(=O)(=O)O)C(C(C(C(C(C(F)(F)F)(F)F)(F)F)(F)...  0.120482
# 8   C(CS(=O)(=O)O)C(C(C(C(C(C(F)(F)F)(F)F)(F)F)(F)...  0.283617
# 9   C(CS(=O)(=O)O)C(C(C(C(C(C(F)(F)F)(F)F)(F)F)(F)...  0.130859
# 10  C(CS(=O)(=O)O)C(C(C(C(C(C(F)(F)F)(F)F)(F)F)(F)...  0.547850
# 11  C(CS(=O)(=O)O)C(C(C(C(C(C(F)(F)F)(F)F)(F)F)(F)...  0.549188
# 12  C(CS(=O)(=O)O)C(C(C(C(C(C(F)(F)F)(F)F)(F)F)(F)...  0.139321
# 13  C(CS(=O)(=O)O)C(C(C(C(C(C(F)(F)F)(F)F)(F)F)(F)...  0.365632
# 14  C(CS(=O)(=O)O)C(C(C(C(C(C(F)(F)F)(F)F)(F)F)(F)...  0.407614
# 15  C(CS(=O)(=O)O)C(C(C(C(C(C(F)(F)F)(F)F)(F)F)(F)...  0.773853
# 16  C(CS(=O)(=O)O)C(C(C(C(C(C(F)(F)F)(F)F)(F)F)(F)...  0.717637
# 17  C(CS(=O)(=O)O)C(C(C(C(C(C(F)(F)F)(F)F)(F)F)(F)...  0.270582
# 18  C(CS(=O)(=O)O)C(C(C(C(C(C(F)(F)F)(F)F)(F)F)(F)...  0.513277
# 19  C(CS(=O)(=O)O)C(C(C(C(C(C(F)(F)F)(F)F)(F)F)(F)...  0.213247
# 20                                       CCCCCCCCCC=O  0.498052
# 21                                       CCCCCCCCCC=O  0.141868
# 22                                       CCCCCCCCCC=O  0.290246
# 23                                       CCCCCCCCCC=O  0.816283
# 24                                       CCCCCCCCCC=O  0.295108
# 25                                       CCCCCCCCCC=O  0.356648
# 26                                       CCCCCCCCCC=O  0.816543
# 27                                       CCCCCCCCCC=O  0.580934
# 28                                       CCCCCCCCCC=O  0.342196
# 29                                       CCCCCCCCCC=O  0.494996
# 30                                       CCCCCCCCCC=O  0.520430
# 31                                       CCCCCCCCCC=O  0.316732
# 32                                       CCCCCCCCCC=O  0.578523
# 33                                       CCCCCCCCCC=O  0.296302
# 34                                       CCCCCCCCCC=O  0.257482
# 35                                       CCCCCCCCCC=O  0.448021
# 36                                       CCCCCCCCCC=O  0.702425
# 37                                       CCCCCCCCCC=O  0.556048
# 38                                       CCCCCCCCCC=O  0.079687
# 39                                       CCCCCCCCCC=O  0.166250
# 40                             CCCC/C=C\CCCCCCCC(=O)O  0.394319
# 41                             CCCC/C=C\CCCCCCCC(=O)O  0.177501
# 42                             CCCC/C=C\CCCCCCCC(=O)O  0.351497
# 43                             CCCC/C=C\CCCCCCCC(=O)O  0.583721
# 44                             CCCC/C=C\CCCCCCCC(=O)O  0.004526
# 45                             CCCC/C=C\CCCCCCCC(=O)O  0.152865
# 46                             CCCC/C=C\CCCCCCCC(=O)O  0.089872
# 47                             CCCC/C=C\CCCCCCCC(=O)O  0.493607
# 48                             CCCC/C=C\CCCCCCCC(=O)O  0.060319
# 49                             CCCC/C=C\CCCCCCCC(=O)O  0.324426
#
#                       smi7     conc7  vesicles_formation
# 0   CCCCCCCCCC(=O)OCC(CO)O  0.534996                1.00
# 1   CCCCCCCCCC(=O)OCC(CO)O  0.147182                1.00
# 2   CCCCCCCCCC(=O)OCC(CO)O  0.269056                1.00
# 3   CCCCCCCCCC(=O)OCC(CO)O  0.075736                1.00
# 4   CCCCCCCCCC(=O)OCC(CO)O  0.434063                1.00
# 5   CCCCCCCCCC(=O)OCC(CO)O  0.047657                1.00
# 6   CCCCCCCCCC(=O)OCC(CO)O  0.089773                1.00
# 7   CCCCCCCCCC(=O)OCC(CO)O  0.190429                1.00
# 8   CCCCCCCCCC(=O)OCC(CO)O  0.564080                1.00
# 9   CCCCCCCCCC(=O)OCC(CO)O  0.401907                1.00
# 10  CCCCCCCCCC(=O)OCC(CO)O  0.638995                1.00
# 11  CCCCCCCCCC(=O)OCC(CO)O  0.505066                1.00
# 12  CCCCCCCCCC(=O)OCC(CO)O  0.317686                1.00
# 13  CCCCCCCCCC(=O)OCC(CO)O  0.582106                1.00
# 14  CCCCCCCCCC(=O)OCC(CO)O  0.338983                1.00
# 15  CCCCCCCCCC(=O)OCC(CO)O  0.221184                1.00
# 16  CCCCCCCCCC(=O)OCC(CO)O  0.540916                1.00
# 17  CCCCCCCCCC(=O)OCC(CO)O  0.094685                1.00
# 18  CCCCCCCCCC(=O)OCC(CO)O  0.649356                1.00
# 19  CCCCCCCCCC(=O)OCC(CO)O  0.037312                1.00
# 20  CCCCCCCCCC(=O)OCC(CO)O  0.628319                1.00
# 21  CCCCCCCCCC(=O)OCC(CO)O  0.654841                1.00
# 22  CCCCCCCCCC(=O)OCC(CO)O  0.594151                1.00
# 23  CCCCCCCCCC(=O)OCC(CO)O  0.167421                0.00
# 24  CCCCCCCCCC(=O)OCC(CO)O  0.387985                0.00
# 25  CCCCCCCCCC(=O)OCC(CO)O  0.158644                1.00
# 26  CCCCCCCCCC(=O)OCC(CO)O  0.319094                0.00
# 27  CCCCCCCCCC(=O)OCC(CO)O  0.374289                0.00
# 28  CCCCCCCCCC(=O)OCC(CO)O  0.176986                1.00
# 29  CCCCCCCCCC(=O)OCC(CO)O  0.034881                1.00
# 30  CCCCCCCCCC(=O)OCC(CO)O  0.205419                0.00
# 31  CCCCCCCCCC(=O)OCC(CO)O  0.621606                0.00
# 32  CCCCCCCCCC(=O)OCC(CO)O  0.295557                0.00
# 33  CCCCCCCCCC(=O)OCC(CO)O  0.157106                1.00
# 34  CCCCCCCCCC(=O)OCC(CO)O  0.556932                0.00
# 35  CCCCCCCCCC(=O)OCC(CO)O  0.282394                0.00
# 36  CCCCCCCCCC(=O)OCC(CO)O  0.669770                0.00
# 37  CCCCCCCCCC(=O)OCC(CO)O  0.610644                0.00
# 38  CCCCCCCCCC(=O)OCC(CO)O  0.210176                0.00
# 39  CCCCCCCCCC(=O)OCC(CO)O  0.364016                1.00
# 40     CCCCCCCCOC(=O)CN.Cl  0.222014                0.97
# 41     CCCCCCCCOC(=O)CN.Cl  0.239710                0.96
# 42     CCCCCCCCOC(=O)CN.Cl  0.294152                0.96
# 43     CCCCCCCCOC(=O)CN.Cl  0.112039                0.96
# 44     CCCCCCCCOC(=O)CN.Cl  0.659746                0.96
# 45     CCCCCCCCOC(=O)CN.Cl  0.032359                0.96
# 46     CCCCCCCCOC(=O)CN.Cl  0.338423                0.95
# 47     CCCCCCCCOC(=O)CN.Cl  0.345057                0.95
# 48     CCCCCCCCOC(=O)CN.Cl  0.480055                0.94
# 49     CCCCCCCCOC(=O)CN.Cl  0.454580                0.94

# %%
# Get latent space from foundation model
x_latent = get_latent_space(df_hierarchical)
x_latent.shape
# Out:
# Random Seed: 12345
# Using Rotation Embedding
# Using Rotation Embedding
# Using Rotation Embedding
# Using Rotation Embedding
# Using Rotation Embedding
# Using Rotation Embedding
# Using Rotation Embedding
# Using Rotation Embedding
# Using Rotation Embedding
# Using Rotation Embedding
# Using Rotation Embedding
# Using Rotation Embedding
# /Users/haoliu/anaconda3/envs/ActiveLearning/lib/python3.11/site-packages/numpy/core/fromnumeric.py:59: FutureWarning: 'Series.swapaxes' is deprecated and will be removed in a future version. Please use 'Series.transpose' instead.
#   return bound(*args, **kwds)
# Vocab size: 2393
# [INFERENCE MODE - smi-ted-Light]
# 100%|██████████| 13/13 [00:03<00:00,  4.22it/s]
# /Users/haoliu/Documents/GitHub/FoundationModel_on_Liposome/code/notebooks/../src/utils.py:80: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df_train_emb = train_df.applymap(lambda x: replace_with_list(x, train_dict))
# (50, 768)

# %%
import joblib

joblib.dump(x_latent, 'x_latent_finetune_search.joblib')
# Out:
# ['x_latent_finetune_search.joblib']

# %%
# Reformatting
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE


subset_colors = {
    "high_replace3_dissimilar_finetune": "tab:blue",
    "high_replace3_dissimilar": "tab:orange",
    "low_replace5_smi_finetune": "tab:green",
    "low_replace5_smi": "tab:red",
    "high_replace5_smi_finetune": "tab:purple"
}

pretty_labels = {
    "high_replace3_dissimilar_finetune": "Replace 3 fluorocarbon after finetuning (high probability)",
    "high_replace3_dissimilar": "Replace 3 fluorocarbon before finetuning (high probability)",
    "low_replace5_smi_finetune": "Replace 5 hydrocarbon after finetuning (low probability)",
    "low_replace5_smi": "Replace 5 hydrocarbon before finetuning (low probability)",
    "high_replace5_smi_finetune": "Replace 5 hydrocarbon after finetuning (high probability)"
}

pca = PCA(n_components=2, random_state=129)
x_pca = pca.fit_transform(x_latent)

plt.figure(figsize=(8, 7))
for subset in np.unique(group_labels):
    idx = np.where(group_labels == subset)
    plt.scatter(
        x_pca[idx, 0], x_pca[idx, 1],
        color=subset_colors[subset],
        label=pretty_labels[subset],   
        s=50, alpha=0.8
    )

plt.xlabel("PC1", fontsize=20)
plt.ylabel("PC2", fontsize=20)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
# plt.title("PCA of Latent Space", fontsize=16)
# Legend above the plot, centered
plt.legend(
    fontsize=12,
    loc="lower center",
    bbox_to_anchor=(0.5, 1.05),   
    ncol=1,                      
    frameon=False                 
)

plt.tight_layout()
plt.savefig("../../results/PCA_finetune_search.png", dpi=600, bbox_inches="tight")

plt.show()
