# %% [markdown]
# - Get latent space for amphiphiles using chemeleon
# - Based on data that derived from different weighting function

# %%
import sys
sys.path.append("../src/models")
sys.path.append("../src")

# %%
import pandas as pd
import numpy as np

from weighting_function import *

# %%
df_structured_ori = pd.read_csv('../../data/weight_function_data/df_structured_ori.csv')
df_structured_mf = pd.read_csv('../../data/weight_function_data/df_structured_mol_frac.csv')

# %%
df_total_ori = prepare_latent_dataset_chemeleon(df_structured_ori)
df_total_mf = prepare_latent_dataset_chemeleon(df_structured_mf)

# %%
df_total_ori.shape
# Out:
# (336, 2049)

# %%
df_total_ori.to_csv('../../data/weight_function_data/df_total_amphiphiles_chemeleon_wf_ori.csv', index=False)
df_total_mf.to_csv('../../data/weight_function_data/df_total_amphiphiles_chemeleon_wf_mf.csv', index=False)
