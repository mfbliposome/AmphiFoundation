# %% [markdown]
# - Get latent space for amphiphiles using smi-ted

# %%
import sys
sys.path.append("../src/models")
sys.path.append("../src")

# %%
import pandas as pd
import numpy as np

# %%
from utils import *
from weighting_function import *

# %%
df_structured_ori = pd.read_csv('../../data/weight_function_data/df_structured_ori.csv')
df_structured_mf = pd.read_csv('../../data/weight_function_data/df_structured_mol_frac.csv')

# %%
df_total_ori = prepare_latent_dataset_am(df_structured_ori, get_latent_space)
# Out:
# Random Seed: 12345
# Using Rotation Embedding
# Using Rotation Embedding
# Using Rotation Embedding
# Using Rotation Embedding
# Using Rotation Embedding
# Using Rotation Embedding
# Using Rotation Embedding
# Using Rotation Embedding
# Using Rotation Embedding
# Using Rotation Embedding
# Using Rotation Embedding
# Using Rotation Embedding
# /Users/haoliu/anaconda3/envs/ActiveLearning/lib/python3.11/site-packages/numpy/core/fromnumeric.py:59: FutureWarning: 'Series.swapaxes' is deprecated and will be removed in a future version. Please use 'Series.transpose' instead.
#   return bound(*args, **kwds)
# Vocab size: 2393
# [INFERENCE MODE - smi-ted-Light]
# 100%|██████████| 7/7 [00:01<00:00,  6.62it/s]
# /Users/haoliu/Documents/GitHub/FoundationModel_on_Liposome/code/notebooks/../src/utils.py:80: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df_train_emb = train_df.applymap(lambda x: replace_with_list(x, train_dict))

# %%
df_total_mf = prepare_latent_dataset_am(df_structured_mf, get_latent_space)
# Out:
# Random Seed: 12345
# Using Rotation Embedding
# Using Rotation Embedding
# Using Rotation Embedding
# Using Rotation Embedding
# Using Rotation Embedding
# Using Rotation Embedding
# Using Rotation Embedding
# Using Rotation Embedding
# Using Rotation Embedding
# Using Rotation Embedding
# Using Rotation Embedding
# Using Rotation Embedding
# /Users/haoliu/anaconda3/envs/ActiveLearning/lib/python3.11/site-packages/numpy/core/fromnumeric.py:59: FutureWarning: 'Series.swapaxes' is deprecated and will be removed in a future version. Please use 'Series.transpose' instead.
#   return bound(*args, **kwds)
# Vocab size: 2393
# [INFERENCE MODE - smi-ted-Light]
# 100%|██████████| 7/7 [00:06<00:00,  1.15it/s]
# /Users/haoliu/Documents/GitHub/FoundationModel_on_Liposome/code/notebooks/../src/utils.py:80: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df_train_emb = train_df.applymap(lambda x: replace_with_list(x, train_dict))

# %%
df_total_ori.to_csv('../../data/weight_function_data/df_total_amphiphiles_smi-ted_wf_ori.csv', index=False)
df_total_mf.to_csv('../../data/weight_function_data/df_total_amphiphiles_smi-ted_wf_mf.csv', index=False)
