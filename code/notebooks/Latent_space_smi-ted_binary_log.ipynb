# %% [markdown]
# - This notebook is to get latent space for binary dataset by using normalization(log) for weight

# %%
import sys
sys.path.append("../src/models")
sys.path.append("../src")
sys.path.append("../")

# %%
import pandas as pd
import numpy as np
from miscibility import *

# %%
df_mixture = pd.read_csv('df_mixture_20250502.csv')
df_mixture
# Out:
# /Users/haoliu/anaconda3/envs/ActiveLearning/lib/python3.11/site-packages/rdkit/Chem/PandasPatcher.py:132: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   for col in df_subset.columns[df_subset.applymap(MolFormatter.is_mol).any()]
#                                                    smi1       conc1  \
# 0     C[C@H](CCC(=O)NCCC[N+](C)(C)CCCS(=O)(=O)[O-])[...  162.628070
# 1     C[C@H](CCC(=O)NCCC[N+](C)(C)CCCS(=O)(=O)[O-])[...  162.628070
# 2     C[C@H](CCC(=O)NCCC[N+](C)(C)CCCS(=O)(=O)[O-])[...  162.628070
# 3     C[C@H](CCC(=O)NCCC[N+](C)(C)CCCS(=O)(=O)[O-])[...  162.628070
# 4     C[C@H](CCC(=O)NCCC[N+](C)(C)CCCS(=O)(=O)[O-])[...  162.628070
# ...                                                 ...         ...
# 1373  C(C(=O)[O-])C(CC(=O)[O-])(C(=O)[O-])O.[Na+].[N...  503.680744
# 1374  C(C(=O)[O-])C(CC(=O)[O-])(C(=O)[O-])O.[Na+].[N...  503.680744
# 1375  C[C@H](CCC(=O)[O-])[C@H]1CC[C@@H]2[C@@]1([C@H]...  361.794501
# ...

# %%
df_train_emb, x_smi = get_latent_space_m_log(df_mixture)
# Out:
# Random Seed: 12345
# Using Rotation Embedding
# Using Rotation Embedding
# Using Rotation Embedding
# Using Rotation Embedding
# Using Rotation Embedding
# Using Rotation Embedding
# Using Rotation Embedding
# Using Rotation Embedding
# Using Rotation Embedding
# Using Rotation Embedding
# Using Rotation Embedding
# Using Rotation Embedding
# /Users/haoliu/anaconda3/envs/ActiveLearning/lib/python3.11/site-packages/numpy/core/fromnumeric.py:59: FutureWarning: 'Series.swapaxes' is deprecated and will be removed in a future version. Please use 'Series.transpose' instead.
#   return bound(*args, **kwds)
# Vocab size: 2393
# [INFERENCE MODE - smi-ted-Light]
# 100%|██████████| 53/53 [00:41<00:00,  1.28it/s]
# /Users/haoliu/Documents/GitHub/FoundationModel_on_Liposome/code/notebooks/../src/miscibility.py:139: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df_train_emb = train_df.applymap(lambda x: replace_with_list(x, train_dict))

# %%
df_train_emb
# Out:
# /Users/haoliu/anaconda3/envs/ActiveLearning/lib/python3.11/site-packages/rdkit/Chem/PandasPatcher.py:132: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   for col in df_subset.columns[df_subset.applymap(MolFormatter.is_mol).any()]
#                                                    smi1     conc1  \
# 0     [0.43436628580093384, -0.5092665553092957, 0.0...  5.097596
# 1     [0.43436628580093384, -0.5092665553092957, 0.0...  5.097596
# 2     [0.43436628580093384, -0.5092665553092957, 0.0...  5.097596
# 3     [0.43436628580093384, -0.5092665553092957, 0.0...  5.097596
# 4     [0.43436628580093384, -0.5092665553092957, 0.0...  5.097596
# ...                                                 ...       ...
# 1373  [0.4185633063316345, -0.47678717970848083, 0.0...  6.223926
# 1374  [0.4185633063316345, -0.47678717970848083, 0.0...  6.223926
# 1375  [0.4031590521335602, -0.4673979878425598, 0.10...  5.893837
# ...

# %%
df_total = pd.concat([x_smi, df_train_emb['miscibility']],axis=1)
df_total
# Out:
# /Users/haoliu/anaconda3/envs/ActiveLearning/lib/python3.11/site-packages/rdkit/Chem/PandasPatcher.py:132: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   for col in df_subset.columns[df_subset.applymap(MolFormatter.is_mol).any()]
#              0         1         2         3         4         5          6  \
# 0     4.242647 -5.160931  0.764908  3.825553  4.820506 -7.572397  11.663607
# 1     3.739219 -4.575222  0.584424  3.365068  3.825598 -6.854185   9.529813
# 2     4.013467 -4.482123  0.396649  3.418492  4.312810 -6.625148   9.999270
# 3     3.022968 -3.603454  0.548637  2.587662  3.115360 -5.679733   7.884792
# 4     3.031818 -3.634900  0.561012  2.590173  2.965796 -5.456233   7.686985
# ...        ...       ...       ...       ...       ...       ...        ...
# 1373  4.526650 -5.290226  1.275886  5.652429  5.854206 -8.605068  13.686417
# 1374  4.861557 -5.936557  0.918870  6.138018  5.049902 -8.026691  12.828063
# ...

# %%
df_total.to_csv('df_total_binary_SMI-TED_log_20250930.csv', index=False)
