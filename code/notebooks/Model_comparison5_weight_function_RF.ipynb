# %% [markdown]
# - Model comparision for RF model with different weighting functions

# %%
import sys
sys.path.append("../src/models")
sys.path.append("../src")

# %%
import os
import joblib
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker


import warnings
warnings.filterwarnings("ignore")

# %%
from model_comparison import *

# %%
# Baseline
df02_ori = pd.read_csv('../../data/weight_function_data/df_total_binary_baseline_wf_ori.csv')
df02_mf = pd.read_csv('../../data/Intermediate/df_combined_bm_baseline_20250527.csv')

df03_ori = pd.read_csv('../../data/weight_function_data/df_total_amphiphiles_baseline_wf_ori.csv')
df03_mf = pd.read_csv('../../data/weight_function_data/df_total_amphiphiles_baseline_wf_mf.csv')

# VICGAE
df12_ori = pd.read_csv('../../data/weight_function_data/df_total_binary_VICGAE_wf_ori.csv')
df12_mf = pd.read_csv('../../data/Intermediate/df_total_binary_VICGAE_20250707.csv')

df13_ori = pd.read_csv('../../data/weight_function_data/df_total_amphiphiles_VICGAE_wf_ori.csv')
df13_mf = pd.read_csv('../../data/weight_function_data/df_total_amphiphiles_VICGAE_wf_mf.csv')

# Chemprop
df22_ori = pd.read_csv('../../data/weight_function_data/df_total_binary_chemprop_wf_ori.csv')
df22_mf = pd.read_csv('../../data/Intermediate/df_total_binary_chemprop_20250707.csv')

df23_ori = pd.read_csv('../../data/weight_function_data/df_total_amphiphiles_chemprop_wf_ori.csv')
df23_mf = pd.read_csv('../../data/weight_function_data/df_total_amphiphiles_chemprop_wf_mf.csv')

# Chemeleon
df32_ori = pd.read_csv('../../data/weight_function_data/df_total_binary_chemeleon_wf_ori.csv')
df32_mf = pd.read_csv('../../data/Intermediate/df_total_binary_chemeleon_20250707.csv')

df33_ori = pd.read_csv('../../data/weight_function_data/df_total_amphiphiles_chemeleon_wf_ori.csv')
df33_mf = pd.read_csv('../../data/weight_function_data/df_total_amphiphiles_chemeleon_wf_mf.csv')

# SMI-TED
df42_ori = pd.read_csv('../../data/weight_function_data/df_total_binary_smi-ted_wf_ori.csv')
df42_mf = pd.read_csv('../../data/Intermediate/df_total_20250501.csv')

df43_ori = pd.read_csv('../../data/weight_function_data/df_total_amphiphiles_smi-ted_wf_ori.csv')
df43_mf = pd.read_csv('../../data/weight_function_data/df_total_amphiphiles_smi-ted_wf_mf.csv')

# %%
# Run the model and visualize latent space

# %%
# For binary system data
model_type = ['Baseline', 'VICGAE', 'Chemprop', 'Chemeleon', 'SMI-TED']
dfs = [df02_ori, df12_ori, df22_ori, df32_ori, df42_ori]

results_dict2 = {}

for df, model in zip(dfs, model_type):
    print(model)
    results_df = evaluate_model_performance_d(df, label_col = 'miscibility', data_type='binary_system', model_type=model,
                                             save_dir="../../results/binary_wf_ori")
    results_dict2[model] = results_df
    visualize_latent_space(df, data_type='binary_system', model_type=model, save_dir="../../results/binary_wf_ori_latent")
# Out:
# Baseline
# ROC-AUC Score: 0.7954
# ROC-AUC Score: 0.8454
# ROC-AUC Score: 0.8002
# ROC-AUC Score: 0.8457
# ROC-AUC Score: 0.7674
# ROC-AUC Score: 0.7848
# ROC-AUC Score: 0.8547
# ROC-AUC Score: 0.8238
# ROC-AUC Score: 0.8467
# ROC-AUC Score: 0.7901
# OMP: Info #276: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.
# VICGAE
# ROC-AUC Score: 0.6785
# ROC-AUC Score: 0.7635
# ROC-AUC Score: 0.6916
# ROC-AUC Score: 0.6855
# ROC-AUC Score: 0.6770
# ROC-AUC Score: 0.6669
# ROC-AUC Score: 0.7164
# ROC-AUC Score: 0.7359
# ROC-AUC Score: 0.6960
# ROC-AUC Score: 0.6998
# Chemprop
# ROC-AUC Score: 0.7576
# ROC-AUC Score: 0.7237
# ROC-AUC Score: 0.6608
# ROC-AUC Score: 0.7255
# ROC-AUC Score: 0.7473
# ROC-AUC Score: 0.6819
# ROC-AUC Score: 0.7427
# ROC-AUC Score: 0.7069
# ROC-AUC Score: 0.7710
# ROC-AUC Score: 0.7600
# Chemeleon
# ROC-AUC Score: 0.8126
# ROC-AUC Score: 0.8207
# ROC-AUC Score: 0.7680
# ROC-AUC Score: 0.8354
# ROC-AUC Score: 0.7893
# ...

# %%
joblib.dump(results_dict2, "../../data/Intermediate/results_dict2_binary_ori.pkl")
# Out:
# ['results_dict2_binary_ori.pkl']

# %%
# For amphiphiles data ori
model_type = ['Baseline', 'VICGAE', 'Chemprop', 'Chemeleon', 'SMI-TED']
dfs = [df03_ori, df13_ori, df23_ori, df33_ori, df43_ori]

results_dict3 = {}

for df, model in zip(dfs, model_type):
    print(model)
    results_df = evaluate_model_performance_d(df, label_col = 'vesicles_formation', data_type='amphiphiles', model_type=model,
                                           save_dir="../../results/amphiphile_wf_ori")
    results_dict3[model] = results_df
    visualize_latent_space(df, data_type='amphiphiles', model_type=model, save_dir="../../results/amphiphile_wf_ori_latent")
# Out:
# Baseline
# ROC-AUC Score: 0.8294
# ROC-AUC Score: 0.8425
# ROC-AUC Score: 0.7982
# ROC-AUC Score: 0.8241
# ROC-AUC Score: 0.8079
# ROC-AUC Score: 0.8513
# ROC-AUC Score: 0.8557
# ROC-AUC Score: 0.8408
# ROC-AUC Score: 0.8868
# ROC-AUC Score: 0.7579
# VICGAE
# ROC-AUC Score: 0.8592
# ROC-AUC Score: 0.8061
# ROC-AUC Score: 0.7404
# ROC-AUC Score: 0.7921
# ROC-AUC Score: 0.8579
# ROC-AUC Score: 0.8803
# ROC-AUC Score: 0.8311
# ROC-AUC Score: 0.8610
# ROC-AUC Score: 0.7851
# ROC-AUC Score: 0.7092
# Chemprop
# ROC-AUC Score: 0.8961
# ROC-AUC Score: 0.7811
# ROC-AUC Score: 0.7680
# ROC-AUC Score: 0.7904
# ROC-AUC Score: 0.8763
# ROC-AUC Score: 0.9241
# ROC-AUC Score: 0.8917
# ROC-AUC Score: 0.8329
# ROC-AUC Score: 0.8259
# ROC-AUC Score: 0.7842
# Chemeleon
# ROC-AUC Score: 0.8776
# ROC-AUC Score: 0.8579
# ROC-AUC Score: 0.8215
# ROC-AUC Score: 0.8531
# ROC-AUC Score: 0.9053
# ROC-AUC Score: 0.9333
# ROC-AUC Score: 0.8978
# ROC-AUC Score: 0.8711
# ROC-AUC Score: 0.9184
# ...

# %%
joblib.dump(results_dict3, "../../data/Intermediate/results_dict3_amphiphile_ori.pkl")
# Out:
# ['results_dict3_amphiphile_ori.pkl']

# %%
# For amphiphiles data mole fraction
model_type = ['Baseline', 'VICGAE', 'Chemprop', 'Chemeleon', 'SMI-TED']
dfs = [df03_mf, df13_mf, df23_mf, df33_mf, df43_mf]

results_dict3 = {}

for df, model in zip(dfs, model_type):
    print(model)
    results_df = evaluate_model_performance_d(df, label_col = 'vesicles_formation', data_type='amphiphiles', model_type=model,
                                             save_dir="../../results/amphiphile_wf_mf")
    results_dict3[model] = results_df
    visualize_latent_space(df, data_type='amphiphiles', model_type=model, save_dir="../../results/amphiphile_wf_mf_latent")
# Out:
# Baseline
# ROC-AUC Score: 0.8132
# ROC-AUC Score: 0.8224
# ROC-AUC Score: 0.7785
# ROC-AUC Score: 0.8206
# ROC-AUC Score: 0.8026
# ROC-AUC Score: 0.8601
# ROC-AUC Score: 0.8570
# ROC-AUC Score: 0.8351
# ROC-AUC Score: 0.7978
# ROC-AUC Score: 0.7399
# VICGAE
# ROC-AUC Score: 0.8368
# ROC-AUC Score: 0.8311
# ROC-AUC Score: 0.8053
# ROC-AUC Score: 0.8206
# ROC-AUC Score: 0.8513
# ROC-AUC Score: 0.8259
# ROC-AUC Score: 0.9268
# ROC-AUC Score: 0.8531
# ROC-AUC Score: 0.7544
# ROC-AUC Score: 0.8140
# Chemprop
# ROC-AUC Score: 0.8162
# ROC-AUC Score: 0.8434
# ROC-AUC Score: 0.8250
# ROC-AUC Score: 0.8333
# ROC-AUC Score: 0.8548
# ROC-AUC Score: 0.8618
# ROC-AUC Score: 0.9219
# ROC-AUC Score: 0.8281
# ROC-AUC Score: 0.8110
# ROC-AUC Score: 0.8825
# Chemeleon
# ROC-AUC Score: 0.8509
# ROC-AUC Score: 0.8425
# ROC-AUC Score: 0.8504
# ROC-AUC Score: 0.8566
# ROC-AUC Score: 0.8833
# ROC-AUC Score: 0.8877
# ROC-AUC Score: 0.9057
# ROC-AUC Score: 0.8658
# ROC-AUC Score: 0.8544
# ...

# %%
joblib.dump(results_dict3, "../../data/Intermediate/results_dict3_amphiphile_mf.pkl")
# Out:
# ['results_dict3_amphiphile_mf.pkl']

# %%
# Plot model performance

# %%
import joblib

# Load the object
results_dict2_wf_ori = joblib.load("../../data/Intermediate/results_dict2_binary_ori.pkl")
results_dict2_wf_log = joblib.load("../../data/Intermediate/results_dict2_RF.pkl")
results_dict2_wf_mf = joblib.load("../../data/Intermediate/results_dict2.pkl")

results_dict3_wf_ori = joblib.load("../../data/Intermediate/results_dict3_amphiphile_ori.pkl")
results_dict3_wf_log = joblib.load("../../data/Intermediate/results_dict3_RF.pkl")
results_dict3_wf_mf = joblib.load("../../data/Intermediate/results_dict3_amphiphile_mf.pkl")

# %%
import joblib

results_log = joblib.load("../../data/Intermediate/results_dict2_RF.pkl")

results_log_clean = {}

for key, value in results_log.items():
    perf_df, model_list = value
    results_log_clean[key] = perf_df  

joblib.dump(results_log_clean, "../../data/Intermediate/results_dict2_RF_clean.pkl")

print("Saved cleaned file: results_dict2_RF_clean.pkl")
# Out:
# Saved cleaned file: results_dict2_RF_clean.pkl

# %%
import matplotlib.pyplot as plt
import numpy as np
import joblib
import pickle

results_ori = joblib.load("../../data/Intermediate/results_dict2_binary_ori.pkl")
results_log = joblib.load("../../data/Intermediate/results_dict2_RF_clean.pkl")
results_mf  = joblib.load("../../data/Intermediate/results_dict2.pkl")

model_type = ['Baseline', 'VICGAE', 'Chemprop', 'Chemeleon', 'SMI-TED']
model_type_name = ['Fingerprint', 'VICGAE', 'Chemprop', 'Chemeleon', 'SMI-TED']
trans_names = ["Linear", "MoleFraction", "Log"]

# Colors for each transform group
colors = ["#1f77b4", "#ff7f0e", "#2ca02c"]


auc_ori = [results_ori[m][0]['roc_auc'].values for m in model_type]
auc_log = [results_log[m]['roc_auc'].values for m in model_type]
auc_mf  = [results_mf[m]['roc_auc'].values for m in model_type]

all_auc = [auc_ori, auc_mf, auc_log]   


plt.figure(figsize=(10, 6))

num_models = len(model_type)
num_groups = len(all_auc)    
box_width = 0.22             
positions = np.arange(num_models)

for i in range(num_groups):
    box_pos = positions + (i - 1) * box_width   # offset each group
    bp = plt.boxplot(
        all_auc[i],
        positions=box_pos,
        widths=box_width,
        patch_artist=True,
        labels=[None]*num_models  # hide builtin labels
    )
    
    # Color the boxes
    for patch in bp['boxes']:
        patch.set_facecolor(colors[i])
        patch.set_alpha(0.5)

plt.xticks(positions, model_type_name, fontsize=16, rotation=15)
plt.ylabel("AUC-ROC Score", fontsize=16)
plt.grid(True, linestyle='--', alpha=0.5)
plt.yticks(fontsize=16)

# Legend
for i, name in enumerate(trans_names):
    plt.plot([], color=colors[i], label=name)
plt.legend(fontsize=14)

plt.tight_layout()

plt.savefig("../../results/model_performance_weight_function_RF_binary.png", dpi=600, bbox_inches="tight")

plt.show()

# %%
results_log = joblib.load("../../data/Intermediate/results_dict3_RF.pkl")

results_log_clean = {}

for key, value in results_log.items():
    perf_df, model_list = value
    results_log_clean[key] = perf_df  

joblib.dump(results_log_clean, "../../data/Intermediate/results_dict3_RF_clean.pkl")

print("Saved cleaned file: results_dict3_RF_clean.pkl")
# Out:
# Saved cleaned file: results_dict3_RF_clean.pkl

# %%
results_ori = joblib.load("../../data/Intermediate/results_dict3_amphiphile_ori.pkl")
results_log = joblib.load("../../data/Intermediate/results_dict3_RF_clean.pkl")
results_mf  = joblib.load("../../data/Intermediate/results_dict3_amphiphile_mf.pkl")

model_type = ['Baseline', 'VICGAE', 'Chemprop', 'Chemeleon', 'SMI-TED']
model_type_name = ['Fingerprint', 'VICGAE', 'Chemprop', 'Chemeleon', 'SMI-TED']
trans_names = ["Linear",  "MoleFraction", "Log"]

# Colors for each transform group
colors = ["#1f77b4", "#ff7f0e", "#2ca02c"]  


auc_ori = [results_ori[m][0]['roc_auc'].values for m in model_type]
auc_log = [results_log[m]['roc_auc'].values for m in model_type]
auc_mf  = [results_mf[m][0]['roc_auc'].values for m in model_type]

all_auc = [auc_ori,  auc_mf, auc_log]   

plt.figure(figsize=(10, 6))

num_models = len(model_type)
num_groups = len(all_auc)    
box_width = 0.22             
positions = np.arange(num_models)

for i in range(num_groups):
    box_pos = positions + (i - 1) * box_width   
    bp = plt.boxplot(
        all_auc[i],
        positions=box_pos,
        widths=box_width,
        patch_artist=True,
        labels=[None]*num_models  
    )
    
    # Color the boxes
    for patch in bp['boxes']:
        patch.set_facecolor(colors[i])
        patch.set_alpha(0.5)

plt.xticks(positions, model_type_name, fontsize=16, rotation=15)
plt.ylabel("AUC-ROC Score", fontsize=16)
plt.grid(True, linestyle='--', alpha=0.5)
plt.yticks(fontsize=16)


for i, name in enumerate(trans_names):
    plt.plot([], color=colors[i], label=name)
plt.legend(fontsize=14)

plt.tight_layout()

plt.savefig("../../results/model_performance_weight_function_RF_amphiphile.png", dpi=600, bbox_inches="tight")

plt.show()
