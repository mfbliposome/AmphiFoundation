# %% [markdown]
# - This notebook is to compare various FM performance on binary data(log normalization)

# %%
import sys
sys.path.append("../src/models")
sys.path.append("../src")
sys.path.append("../")

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import roc_auc_score

# %%
from model_comparison import run_classifier_model, evaluate_model_performance, evaluate_model_performance_regression, visualize_latent_space

# %%
# Baseline
# df01 = pd.read_csv('df_total_surfactants_baseline_20250711.csv')
df02 = pd.read_csv('df_total_binary_baseline_log_20250930.csv')
# df03 = pd.read_csv('df_total_amphiphiles_baseline_20250710.csv')
# VICGAE
# df11 = pd.read_csv('df_total_surfactants_VICGAE_20250707.csv')
df12 = pd.read_csv('df_total_binary_VICGAE_log_20250930.csv')
# df13 = pd.read_csv('df_total_amphiphiles_VICGAE_20250707.csv')
# Chemprop
# df21 = pd.read_csv('df_total_surfactants_chemprop_20250707.csv')
df22 = pd.read_csv('df_total_binary_chemprop_log_20250930.csv')
# df23 = pd.read_csv('df_total_amphiphiles_chemprop_20250707.csv')
# Chemeleon
# df31 = pd.read_csv('df_total_surfactants_chemeleon_20250707.csv')
df32 = pd.read_csv('df_total_binary_chemeleon_log_20250930.csv')
# df33 = pd.read_csv('df_total_amphiphiles_chemleon_20250702.csv')
# SMI-TED
# df41 = pd.read_csv('df_total_surfactants_smi-ted_20250709.csv')
df42 = pd.read_csv('df_total_binary_SMI-TED_log_20250930.csv')
# df43 = pd.read_csv('df_total_amphiphiles_smi-ted_20250709.csv')

# %%
# For binary system data
model_type = ['Baseline', 'VICGAE', 'Chemprop', 'Chemeleon', 'SMI-TED']
dfs = [df02, df12, df22, df32, df42]

results_dict2 = {}

for df, model in zip(dfs, model_type):
    print(model)
    results_df = evaluate_model_performance(df, label_col = 'miscibility', data_type='binary_system', model_type=model, save_plot_name='log_weight', output_csv_name='log_weight')
    results_dict2[model] = results_df
    visualize_latent_space(df, data_type='binary_system', model_type=model)
# Out:
# Baseline
# ROC-AUC Score: 0.7834
# ROC-AUC Score: 0.8174
# ROC-AUC Score: 0.7785
# ROC-AUC Score: 0.8516
# ROC-AUC Score: 0.7573
# ROC-AUC Score: 0.7749
# ROC-AUC Score: 0.8608
# ROC-AUC Score: 0.8092
# ROC-AUC Score: 0.8318
# ROC-AUC Score: 0.7826
# /Users/haoliu/anaconda3/envs/ActiveLearning/lib/python3.11/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/haoliu/anaconda3/envs/ActiveLearning/lib/python3.11/site-packages/umap/umap_.py:1945: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")
# OMP: Info #276: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.
# /Users/haoliu/anaconda3/envs/ActiveLearning/lib/python3.11/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/haoliu/anaconda3/envs/ActiveLearning/lib/python3.11/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/haoliu/anaconda3/envs/ActiveLearning/lib/python3.11/site-packages/umap/umap_.py:1945: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")
# /Users/haoliu/anaconda3/envs/ActiveLearning/lib/python3.11/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/haoliu/anaconda3/envs/ActiveLearning/lib/python3.11/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/haoliu/anaconda3/envs/ActiveLearning/lib/python3.11/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# VICGAE
# ROC-AUC Score: 0.7004
# ROC-AUC Score: 0.7567
# ROC-AUC Score: 0.6748
# ROC-AUC Score: 0.7463
# ROC-AUC Score: 0.6356
# ROC-AUC Score: 0.6833
# ROC-AUC Score: 0.7222
# ROC-AUC Score: 0.6947
# ROC-AUC Score: 0.6964
# ROC-AUC Score: 0.7488
# /Users/haoliu/anaconda3/envs/ActiveLearning/lib/python3.11/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/haoliu/anaconda3/envs/ActiveLearning/lib/python3.11/site-packages/umap/umap_.py:1945: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")
# /Users/haoliu/anaconda3/envs/ActiveLearning/lib/python3.11/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/haoliu/anaconda3/envs/ActiveLearning/lib/python3.11/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/haoliu/anaconda3/envs/ActiveLearning/lib/python3.11/site-packages/umap/umap_.py:1945: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")
# /Users/haoliu/anaconda3/envs/ActiveLearning/lib/python3.11/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/haoliu/anaconda3/envs/ActiveLearning/lib/python3.11/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/haoliu/anaconda3/envs/ActiveLearning/lib/python3.11/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# Chemprop
# ROC-AUC Score: 0.7656
# ROC-AUC Score: 0.7746
# ROC-AUC Score: 0.7399
# ROC-AUC Score: 0.7914
# ROC-AUC Score: 0.7567
# ROC-AUC Score: 0.7343
# ROC-AUC Score: 0.7893
# ROC-AUC Score: 0.7553
# ROC-AUC Score: 0.7649
# ROC-AUC Score: 0.7733
# /Users/haoliu/anaconda3/envs/ActiveLearning/lib/python3.11/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/haoliu/anaconda3/envs/ActiveLearning/lib/python3.11/site-packages/umap/umap_.py:1945: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")
# /Users/haoliu/anaconda3/envs/ActiveLearning/lib/python3.11/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/haoliu/anaconda3/envs/ActiveLearning/lib/python3.11/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/haoliu/anaconda3/envs/ActiveLearning/lib/python3.11/site-packages/umap/umap_.py:1945: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")
# /Users/haoliu/anaconda3/envs/ActiveLearning/lib/python3.11/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/haoliu/anaconda3/envs/ActiveLearning/lib/python3.11/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/haoliu/anaconda3/envs/ActiveLearning/lib/python3.11/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# Chemeleon
# ROC-AUC Score: 0.8164
# ROC-AUC Score: 0.8153
# ROC-AUC Score: 0.7774
# ROC-AUC Score: 0.8348
# ROC-AUC Score: 0.7813
# ROC-AUC Score: 0.7956
# ROC-AUC Score: 0.8468
# ROC-AUC Score: 0.8266
# ROC-AUC Score: 0.8261
# ROC-AUC Score: 0.8479
# /Users/haoliu/anaconda3/envs/ActiveLearning/lib/python3.11/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/haoliu/anaconda3/envs/ActiveLearning/lib/python3.11/site-packages/umap/umap_.py:1945: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")
# /Users/haoliu/anaconda3/envs/ActiveLearning/lib/python3.11/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/haoliu/anaconda3/envs/ActiveLearning/lib/python3.11/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/haoliu/anaconda3/envs/ActiveLearning/lib/python3.11/site-packages/umap/umap_.py:1945: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")
# /Users/haoliu/anaconda3/envs/ActiveLearning/lib/python3.11/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/haoliu/anaconda3/envs/ActiveLearning/lib/python3.11/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/haoliu/anaconda3/envs/ActiveLearning/lib/python3.11/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# SMI-TED
# ROC-AUC Score: 0.7851
# ROC-AUC Score: 0.7994
# ROC-AUC Score: 0.7436
# ROC-AUC Score: 0.8282
# ROC-AUC Score: 0.7747
# ROC-AUC Score: 0.7518
# ROC-AUC Score: 0.8413
# ROC-AUC Score: 0.7875
# ROC-AUC Score: 0.8109
# ROC-AUC Score: 0.8173
# /Users/haoliu/anaconda3/envs/ActiveLearning/lib/python3.11/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/haoliu/anaconda3/envs/ActiveLearning/lib/python3.11/site-packages/umap/umap_.py:1945: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")
# /Users/haoliu/anaconda3/envs/ActiveLearning/lib/python3.11/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/haoliu/anaconda3/envs/ActiveLearning/lib/python3.11/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/haoliu/anaconda3/envs/ActiveLearning/lib/python3.11/site-packages/umap/umap_.py:1945: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")
# /Users/haoliu/anaconda3/envs/ActiveLearning/lib/python3.11/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/haoliu/anaconda3/envs/ActiveLearning/lib/python3.11/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/haoliu/anaconda3/envs/ActiveLearning/lib/python3.11/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(

# %%
import joblib
joblib.dump(results_dict2, "results_dict2_log.pkl")
# Out:
# ['results_dict2_log.pkl']

# %%
# For binary system data
model_type = ['Baseline', 'VICGAE', 'Chemprop', 'Chemeleon', 'SMI-TED']
dfs = [df02, df12, df22, df32, df42]

results_dict2 = {}

for df, model in zip(dfs, model_type):
    print(model)
    results_df = evaluate_model_performance(df, label_col = 'miscibility', data_type='binary_system', model_type=model, save_plot_name='log_weight', output_csv_name='log_weight')
    results_dict2[model] = results_df
    # visualize_latent_space(df, data_type='binary_system', model_type=model)
# Out:
# Baseline
# ROC-AUC Score: 0.7834
# ROC-AUC Score: 0.8174
# ROC-AUC Score: 0.7785
# ROC-AUC Score: 0.8516
# ROC-AUC Score: 0.7573
# ROC-AUC Score: 0.7749
# ROC-AUC Score: 0.8608
# ROC-AUC Score: 0.8092
# ROC-AUC Score: 0.8318
# ROC-AUC Score: 0.7826
# VICGAE
# ROC-AUC Score: 0.7004
# ROC-AUC Score: 0.7567
# ROC-AUC Score: 0.6748
# ROC-AUC Score: 0.7463
# ROC-AUC Score: 0.6356
# ROC-AUC Score: 0.6833
# ROC-AUC Score: 0.7222
# ROC-AUC Score: 0.6947
# ROC-AUC Score: 0.6964
# ROC-AUC Score: 0.7488
# Chemprop
# ROC-AUC Score: 0.7656
# ROC-AUC Score: 0.7746
# ROC-AUC Score: 0.7399
# ROC-AUC Score: 0.7914
# ROC-AUC Score: 0.7567
# ROC-AUC Score: 0.7343
# ROC-AUC Score: 0.7893
# ROC-AUC Score: 0.7553
# ROC-AUC Score: 0.7649
# ROC-AUC Score: 0.7733
# Chemeleon
# ROC-AUC Score: 0.8164
# ROC-AUC Score: 0.8153
# ROC-AUC Score: 0.7774
# ROC-AUC Score: 0.8348
# ROC-AUC Score: 0.7813
# ROC-AUC Score: 0.7956
# ROC-AUC Score: 0.8468
# ROC-AUC Score: 0.8266
# ROC-AUC Score: 0.8261
# ROC-AUC Score: 0.8479
# SMI-TED
# ROC-AUC Score: 0.7851
# ROC-AUC Score: 0.7994
# ROC-AUC Score: 0.7436
# ROC-AUC Score: 0.8282
# ROC-AUC Score: 0.7747
# ROC-AUC Score: 0.7518
# ROC-AUC Score: 0.8413
# ROC-AUC Score: 0.7875
# ROC-AUC Score: 0.8109
# ROC-AUC Score: 0.8173

# %%
import joblib
joblib.dump(results_dict2, "results_dict2_log_update.pkl")
# Out:
# ['results_dict2_log_update.pkl']

# %%
# Redesign plot
model_type = ['Baseline', 'VICGAE', 'Chemprop', 'Chemeleon', 'SMI-TED']

# Extract the AUC lists from the dictionary you showed
auc_lists = [results_dict2[model]['roc_auc'].values for model in model_type]

# Create the boxplot
plt.figure(figsize=(8, 5))
box = plt.boxplot(auc_lists, patch_artist=True, labels=model_type)

# Customize box colors
for patch in box['boxes']:
    patch.set_facecolor('#1f77b4')
    patch.set_alpha(0.6)

# Labels and styling
plt.ylabel('AUC-ROC Score', fontsize=16)
# plt.xlabel('Model Type', fontsize=16)
# plt.title('AUC-ROC Score Across Models (ATPs)', fontsize=16)
plt.grid(True, linestyle='--', alpha=0.5)
plt.xticks(fontsize=16, rotation=15)
# plt.xticks(ticks=range(1, len(model_type) + 1), labels=[""] * len(model_type))

plt.yticks(fontsize=16)
plt.tight_layout()
plt.savefig("../results/ATPs_model_performance_log.png", dpi=600, bbox_inches="tight")

plt.show()
